# %%
from vpython import *
from math import sin, cos, pi, sqrt, atan2

screen = canvas(title='VPython Simulation', width=900, height=600)
screen.background = color.gray(0.5)

box(pos=vec(0,0,0), size=vec(10,10,10), color=color.red)

t = 0
while True:
    rate(60)
    t += 0.02
